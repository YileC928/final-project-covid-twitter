# %%
import json
import pandas as pd
import preprocessor as p
import nltk
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import TweetTokenizer

import spacy

# %%
try:
    nlp = spacy.load("en")
except OSError:
    nlp = spacy.load("en_core_web_sm")

# %%
tweets = []
for line in open('data/cdc_twitter_covid.json', 'r', encoding='utf-8'):
    tweets.append(json.loads(line))
    
df = pd.DataFrame(tweets)

# %%
df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
df = df[['id', 'date', 'time', 'username', 'tweet', 'mentions','urls', 'photos', 'hashtags', 'link', 'quote_url']]

# %%
tweets_df = df[['id', 'date', 'time', 'username', 'tweet', 'hashtags']]
tweets_df
# Out:
#                       id        date      time username  \
# 0    1363921515922796547  2021-02-22  13:40:04   cdcgov
# 1    1363885801755533313  2021-02-22  11:18:09   cdcgov
# 2    1362865816765661190  2021-02-19  15:45:06   cdcgov
# 3    1362849192130080772  2021-02-19  14:39:02   cdcgov
# 4    1362510972162867206  2021-02-18  16:15:04   cdcgov
# ..                   ...         ...       ...      ...
# 426  1233891883195211780  2020-02-29  18:08:44   cdcgov
# 427  1233891113628557313  2020-02-29  18:05:40   cdcgov
# 428  1233891108654108672  2020-02-29  18:05:39   cdcgov
# 429  1233486735578976257  2020-02-28  15:18:49   cdcgov
# 430  1232366410313224193  2020-02-25  13:07:03   cdcgov
#
#                                                  tweet              hashtags
# 0    #DYK? COVID-19 and flu can both cause fever an...        [dyk, covid19]
# 1    A new @CDCMMWR looks at #COVID19 in Georgia el...             [covid19]
# 2    Officials are concerned about 3 #COVID19 varia...             [covid19]
# 3    Getting a #COVID19 vaccine is important for ad...             [covid19]
# 4    #DYK? You need two #COVID19 mRNA vaccine doses...        [dyk, covid19]
# ..                                                 ...                   ...
# 426  Reports of community spread of #COVID19 in Cal...             [covid19]
# 427  CDC, @WADeptHealth &amp; @KCPubHealth also rep...               [covid]
# 428  Today, @WADeptHealth and CDC reported the deat...  [covid, coronavirus]
# 429  CDC does not currently recommend the general p...        [covid19, ppe]
# 430  CDC and public health authorities have impleme...                    []
#
# [431 rows x 6 columns]

# %%
print('--- Print the Basic Info of the data ----')
print(tweets_df.info())
print(tweets_df.shape)

print('--- Print the Head/Tail of the data -----')
print(tweets_df.head())
print('------------------------')
print(tweets_df.tail())
# Out:
# --- Print the Basic Info of the data ----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        431 non-null    int64
#  1   date      431 non-null    object
#  2   time      431 non-null    object
#  3   username  431 non-null    object
#  4   tweet     431 non-null    object
#  5   hashtags  431 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 20.3+ KB
# None
# (431, 6)
# --- Print the Head/Tail of the data -----
#                     id        date      time username  \
# 0  1363921515922796547  2021-02-22  13:40:04   cdcgov
# 1  1363885801755533313  2021-02-22  11:18:09   cdcgov
# 2  1362865816765661190  2021-02-19  15:45:06   cdcgov
# 3  1362849192130080772  2021-02-19  14:39:02   cdcgov
# 4  1362510972162867206  2021-02-18  16:15:04   cdcgov
#
#                                                tweet        hashtags
# 0  #DYK? COVID-19 and flu can both cause fever an...  [dyk, covid19]
# 1  A new @CDCMMWR looks at #COVID19 in Georgia el...       [covid19]
# 2  Officials are concerned about 3 #COVID19 varia...       [covid19]
# 3  Getting a #COVID19 vaccine is important for ad...       [covid19]
# 4  #DYK? You need two #COVID19 mRNA vaccine doses...  [dyk, covid19]
# ------------------------
#                       id        date      time username  \
# 426  1233891883195211780  2020-02-29  18:08:44   cdcgov
# 427  1233891113628557313  2020-02-29  18:05:40   cdcgov
# 428  1233891108654108672  2020-02-29  18:05:39   cdcgov
# 429  1233486735578976257  2020-02-28  15:18:49   cdcgov
# 430  1232366410313224193  2020-02-25  13:07:03   cdcgov
#
#                                                  tweet              hashtags
# 426  Reports of community spread of #COVID19 in Cal...             [covid19]
# 427  CDC, @WADeptHealth &amp; @KCPubHealth also rep...               [covid]
# 428  Today, @WADeptHealth and CDC reported the deat...  [covid, coronavirus]
# 429  CDC does not currently recommend the general p...        [covid19, ppe]
# 430  CDC and public health authorities have impleme...                    []

# %%
# remove URLs, emojis, smileys, mentions, hashtags, and reserved words
for i,v in enumerate(tweets_df['tweet']):
    p.set_options(p.OPT.URL, p.OPT.EMOJI, p.OPT.SMILEY, p.OPT.MENTION, p.OPT.HASHTAG, p.OPT.RESERVED) # options: p.OPT.URL, p.OPT.MENTION, p.OPT.HASHTAG,
                                                                                                #p.OPT.RESERVED, p.OPT.EMOJI, p.OPT.SMILEY,
                                                                                                #p.OPT.NUMBER
    tweets_df.loc[i, 'tweet'] = p.clean(v)
    tweets_df.loc[i, 'tweet'] = tweets_df.loc[i, "tweet"]
# Out:
# C:\Users\xiche\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
tweets_df.loc[0, "tweet"]
# Out:
# '? COVID-19 and flu can both cause fever and cough, but shortness of breath is more common with than flu. Use this chart to learn more about the similarities and differences of COVID-19 and flu. Learn more: .'

# %%
# Remove extra white spaces, punctuation and apply lower casing
tweets_df['tweet'] = tweets_df['tweet'].str.lower().str.replace('[^\w\s]',' ').str.replace('\s\s+', ' ')
tweets_df.loc[0, "tweet"]
# Out:
# <ipython-input-102-e68e07bc12be>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['tweet'] = tweets_df['tweet'].str.lower().str.replace('[^\w\s]',' ').str.replace('\s\s+', ' ')
# ' covid 19 and flu can both cause fever and cough but shortness of breath is more common with than flu use this chart to learn more about the similarities and differences of covid 19 and flu learn more '

# %%
# lemmatize and tokenize
def word_tokenize(word_list, model=nlp, MAX_LEN=1500000):   
    tokenized = []
    if type(word_list) == list and len(word_list) == 1:
        word_list = word_list[0]

    if type(word_list) == list:
        word_list = ' '.join([str(elem) for elem in word_list]) 
    # since we're only tokenizing, I remove RAM intensive operations and increase max text size

    model.max_length = MAX_LEN
    doc = model(word_list, disable=["parser", "tagger", "ner"])
    
    for token in doc:
        if not token.is_punct and len(token.text.strip()) > 0:
            tokenized.append(token.text)
    return tokenized

# %%
def normalizeTokens(word_list, extra_stop=[], model=nlp, lemma=True, MAX_LEN=1500000):
    normalized = []
    if type(word_list) == list and len(word_list) == 1:
        word_list = word_list[0]

    if type(word_list) == list:
        word_list = ' '.join([str(elem) for elem in word_list]) 

    # since we're only normalizing, I remove RAM intensive operations and increase max text size

    model.max_length = MAX_LEN
    doc = model(word_list.lower(), disable=["parser", "tagger", "ner"])

    if len(extra_stop) > 0:
        for stopword in extra_stop:
            lexeme = nlp.vocab[stopword]
            lexeme.is_stop = True

    # check if we want lemmas or not earlier to avoid checking every time we loop
    if lemma:
        for w in doc:
            # if it's not a stop word or punctuation mark, add it to our article
            if w.text != '\n' and not w.is_stop and not w.is_punct and not w.like_num and len(w.text.strip()) > 0:
            # we add the lematized version of the word
                normalized.append(str(w.lemma_))
    else:
        for w in doc:
            # if it's not a stop word or punctuation mark, add it to our article
            if w.text != '\n' and not w.is_stop and not w.is_punct and not w.like_num and len(w.text.strip()) > 0:
            # we add the lematized version of the word
                normalized.append(str(w.text.strip()))

    return normalized

# %%
tweets_df['tokenized_tweet'] = tweets_df['tweet'].apply(lambda x: word_tokenize(x))
tweets_df['normalized_tokens'] = tweets_df['tokenized_tweet'].apply(lambda x: normalizeTokens(x))
# Out:
# <ipython-input-105-8fcd6026113e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['tokenized_tweet'] = tweets_df['tweet'].apply(lambda x: word_tokenize(x))
# <ipython-input-105-8fcd6026113e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['normalized_tokens'] = tweets_df['tokenized_tweet'].apply(lambda x: normalizeTokens(x))

# %%
tweets_df
# Out:
#                       id        date      time username  \
# 0    1363921515922796547  2021-02-22  13:40:04   cdcgov
# 1    1363885801755533313  2021-02-22  11:18:09   cdcgov
# 2    1362865816765661190  2021-02-19  15:45:06   cdcgov
# 3    1362849192130080772  2021-02-19  14:39:02   cdcgov
# 4    1362510972162867206  2021-02-18  16:15:04   cdcgov
# ..                   ...         ...       ...      ...
# 426  1233891883195211780  2020-02-29  18:08:44   cdcgov
# 427  1233891113628557313  2020-02-29  18:05:40   cdcgov
# 428  1233891108654108672  2020-02-29  18:05:39   cdcgov
# 429  1233486735578976257  2020-02-28  15:18:49   cdcgov
# 430  1232366410313224193  2020-02-25  13:07:03   cdcgov
#
#                                                  tweet              hashtags  \
# 0     covid 19 and flu can both cause fever and cou...        [dyk, covid19]
# 1    a new looks at in georgia elementary schools t...             [covid19]
# 2    officials are concerned about 3 variants detec...             [covid19]
# 3    getting a vaccine is important for adults with...             [covid19]
# 4     you need two mrna vaccine doses to get the mo...        [dyk, covid19]
# ..                                                 ...                   ...
# 426  reports of community spread of in california o...             [covid19]
# 427  cdc amp also reported 2 ppl have tested positi...               [covid]
# 428  today and cdc reported the death of a person w...  [covid, coronavirus]
# 429  cdc does not currently recommend the general p...        [covid19, ppe]
# 430  cdc and public health authorities have impleme...                    []
#
#                                        tokenized_tweet  \
# 0    [covid, 19, and, flu, can, both, cause, fever,...
# 1    [a, new, looks, at, in, georgia, elementary, s...
# 2    [officials, are, concerned, about, 3, variants...
# 3    [getting, a, vaccine, is, important, for, adul...
# 4    [you, need, two, mrna, vaccine, doses, to, get...
# ..                                                 ...
# 426  [reports, of, community, spread, of, in, calif...
# 427  [cdc, amp, also, reported, 2, ppl, have, teste...
# 428  [today, and, cdc, reported, the, death, of, a,...
# 429  [cdc, does, not, currently, recommend, the, ge...
# 430  [cdc, and, public, health, authorities, have, ...
#
#                                      normalized_tokens
# 0    [covid, flu, cause, fever, cough, shortness, b...
# 1    [new, look, georgia, elementary, school, study...
# 2    [official, concern, variant, detect, u, s, b, ...
# 3    [get, vaccine, important, adult, certain, heal...
# 4    [need, mrna, vaccine, dose, protection, covid,...
# ..                                                 ...
# 426  [report, community, spread, california, oregon...
# 427  [cdc, amp, report, ppl, test, positive, hospit...
# 428  [today, cdc, report, death, person, hospitaliz...
# 429  [cdc, currently, recommend, general, public, u...
# 430  [cdc, public, health, authority, implement, ag...
#
# [431 rows x 8 columns]

# %%
# save tweets as txt file
#tweets_df["tweet"].to_csv("tweet" + '.txt', index=False)

# %%
tweets_df['year'] = tweets_df['date'].apply(lambda x: x.split('-')[0])
tweets_df['month'] = tweets_df['date'].apply(lambda x: x.split('-')[1])
tweets_df['date'] = tweets_df['date'].apply(lambda x: x.split('-')[2])
# Out:
# <ipython-input-107-fc52ba283241>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['year'] = tweets_df['date'].apply(lambda x: x.split('-')[0])
# <ipython-input-107-fc52ba283241>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['month'] = tweets_df['date'].apply(lambda x: x.split('-')[1])
# <ipython-input-107-fc52ba283241>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['date'] = tweets_df['date'].apply(lambda x: x.split('-')[2])

# %%
tweets_df
# Out:
#                       id date      time username  \
# 0    1363921515922796547   22  13:40:04   cdcgov
# 1    1363885801755533313   22  11:18:09   cdcgov
# 2    1362865816765661190   19  15:45:06   cdcgov
# 3    1362849192130080772   19  14:39:02   cdcgov
# 4    1362510972162867206   18  16:15:04   cdcgov
# ..                   ...  ...       ...      ...
# 426  1233891883195211780   29  18:08:44   cdcgov
# 427  1233891113628557313   29  18:05:40   cdcgov
# 428  1233891108654108672   29  18:05:39   cdcgov
# 429  1233486735578976257   28  15:18:49   cdcgov
# 430  1232366410313224193   25  13:07:03   cdcgov
#
#                                                  tweet              hashtags  \
# 0     covid 19 and flu can both cause fever and cou...        [dyk, covid19]
# 1    a new looks at in georgia elementary schools t...             [covid19]
# 2    officials are concerned about 3 variants detec...             [covid19]
# 3    getting a vaccine is important for adults with...             [covid19]
# 4     you need two mrna vaccine doses to get the mo...        [dyk, covid19]
# ..                                                 ...                   ...
# 426  reports of community spread of in california o...             [covid19]
# 427  cdc amp also reported 2 ppl have tested positi...               [covid]
# 428  today and cdc reported the death of a person w...  [covid, coronavirus]
# 429  cdc does not currently recommend the general p...        [covid19, ppe]
# 430  cdc and public health authorities have impleme...                    []
#
#                                        tokenized_tweet  \
# 0    [covid, 19, and, flu, can, both, cause, fever,...
# 1    [a, new, looks, at, in, georgia, elementary, s...
# 2    [officials, are, concerned, about, 3, variants...
# 3    [getting, a, vaccine, is, important, for, adul...
# 4    [you, need, two, mrna, vaccine, doses, to, get...
# ..                                                 ...
# 426  [reports, of, community, spread, of, in, calif...
# 427  [cdc, amp, also, reported, 2, ppl, have, teste...
# 428  [today, and, cdc, reported, the, death, of, a,...
# 429  [cdc, does, not, currently, recommend, the, ge...
# 430  [cdc, and, public, health, authorities, have, ...
#
#                                      normalized_tokens  year month
# 0    [covid, flu, cause, fever, cough, shortness, b...  2021    02
# 1    [new, look, georgia, elementary, school, study...  2021    02
# 2    [official, concern, variant, detect, u, s, b, ...  2021    02
# 3    [get, vaccine, important, adult, certain, heal...  2021    02
# 4    [need, mrna, vaccine, dose, protection, covid,...  2021    02
# ..                                                 ...   ...   ...
# 426  [report, community, spread, california, oregon...  2020    02
# 427  [cdc, amp, report, ppl, test, positive, hospit...  2020    02
# 428  [today, cdc, report, death, person, hospitaliz...  2020    02
# 429  [cdc, currently, recommend, general, public, u...  2020    02
# 430  [cdc, public, health, authority, implement, ag...  2020    02
#
# [431 rows x 10 columns]

# %%
# %store tweets_df
# Out:
# Stored 'tweets_df' (DataFrame)

# %%
#save cleaned texts as txt file
tweets_df.to_csv("cleaned_tweets" + '.txt', index=False)

# %%
tweets01 = tweets_df[((tweets_df["month"] == '02') |(tweets_df["month"] == '03')) & (tweets_df["year"] == '2020')]
tweets01 = tweets01.reset_index(drop=True)
tweets01
# Out:
#                      id date      time username  \
# 0   1244692113448677378   30  14:24:59   cdcgov
# 1   1244349105343774720   29  15:42:00   cdcgov
# 2   1243960241311678465   28  13:56:47   cdcgov
# 3   1243215392929185794   26  12:37:02   cdcgov
# 4   1242915042049351682   25  16:43:32   cdcgov
# 5   1242147859178360834   23  13:55:02   cdcgov
# 6   1241815661648596994   22  15:55:00   cdcgov
# 7   1241461585140420609   21  16:28:01   cdcgov
# 8   1241353868924948484   21  09:20:00   cdcgov
# 9   1240323954461507585   18  13:07:29   cdcgov
# 10  1238841061277040640   14  10:55:00   cdcgov
# 11  1238500866203803650   13  12:23:11   cdcgov
# 12  1238497404627955713   13  12:09:26   cdcgov
# 13  1238489073456689153   13  11:36:19   cdcgov
# 14  1237125047292133381   09  17:16:10   cdcgov
# 15  1237123947902185482   09  17:11:48   cdcgov
# 16  1236766650382397440   08  17:32:02   cdcgov
# 17  1236736553080229889   08  15:32:26   cdcgov
# 18  1236412783387906048   07  17:05:53   cdcgov
# 19  1235565826473955328   05  09:00:23   cdcgov
# 20  1234968502844432386   03  17:26:50   cdcgov
# 21  1234902513444380673   03  13:04:37   cdcgov
# 22  1233891884742868992   29  18:08:44   cdcgov
# 23  1233891883195211780   29  18:08:44   cdcgov
# 24  1233891113628557313   29  18:05:40   cdcgov
# 25  1233891108654108672   29  18:05:39   cdcgov
# 26  1233486735578976257   28  15:18:49   cdcgov
# 27  1232366410313224193   25  13:07:03   cdcgov
#
#                                                 tweet                hashtags  \
# 0   asymptomatic and pre symptomatic nursing home ...                      []
# 1   take simple daily precautions to help prevent ...               [covid19]
# 2   new cdc health alert network advisory severe i...           [coronavirus]
# 3   parents stay flexible with a learning schedule...                      []
# 4   as of march 25 41 us states and 1 us territory...  [coronavirus, covid19]
# 5   cdc recommends that travelers defer all cruise...               [covid19]
# 6   we all have a role to play to reducing and slo...   [covid19, stayathome]
# 7   a new report in shows serious disease amp deat...                      []
# 8   everyone has a role to play to reduce amp slow...   [covid19, stayathome]
# 9   new in 8 out of 10 deaths associated with occu...               [covid19]
# 10  older adults and people w severe chronic medic...               [covid19]
# 11  q what are the ideal community responses that ...                [askcdc]
# 12  q after an individual is sickened with the cov...                [askcdc]
# 13  as of march 11 81 state and local public healt...                      []
# 14  currently most cases of in the us are in calif...               [covid19]
# 15  there are an estimated 110 000 cases of worldw...               [covid19]
# 16  older adults amp ppl w severe chronic medical ...               [covid19]
# 17  prevention actions for include routinely clean...               [covid19]
# 18  older adults amp people with severe chronic me...                      []
# 19   the coca call today at 2 pm et will also be a...                  [hcps]
# 20  the greatest risk for infection is among those...               [covid19]
# 21  the us public health response to the threat of...               [covid19]
# 22  some people in the us will be at increased ris...               [covid19]
# 23  reports of community spread of in california o...               [covid19]
# 24  cdc amp also reported 2 ppl have tested positi...                 [covid]
# 25  today and cdc reported the death of a person w...    [covid, coronavirus]
# 26  cdc does not currently recommend the general p...          [covid19, ppe]
# 27  cdc and public health authorities have impleme...                      []
#
#                                       tokenized_tweet  \
# 0   [asymptomatic, and, pre, symptomatic, nursing,...
# 1   [take, simple, daily, precautions, to, help, p...
# 2   [new, cdc, health, alert, network, advisory, s...
# 3   [parents, stay, flexible, with, a, learning, s...
# 4   [as, of, march, 25, 41, us, states, and, 1, us...
# 5   [cdc, recommends, that, travelers, defer, all,...
# 6   [we, all, have, a, role, to, play, to, reducin...
# 7   [a, new, report, in, shows, serious, disease, ...
# 8   [everyone, has, a, role, to, play, to, reduce,...
# 9   [new, in, 8, out, of, 10, deaths, associated, ...
# 10  [older, adults, and, people, w, severe, chroni...
# 11  [q, what, are, the, ideal, community, response...
# 12  [q, after, an, individual, is, sickened, with,...
# 13  [as, of, march, 11, 81, state, and, local, pub...
# 14  [currently, most, cases, of, in, the, us, are,...
# 15  [there, are, an, estimated, 110, 000, cases, o...
# 16  [older, adults, amp, ppl, w, severe, chronic, ...
# 17  [prevention, actions, for, include, routinely,...
# 18  [older, adults, amp, people, with, severe, chr...
# 19  [the, coca, call, today, at, 2, pm, et, will, ...
# 20  [the, greatest, risk, for, infection, is, amon...
# 21  [the, us, public, health, response, to, the, t...
# 22  [some, people, in, the, us, will, be, at, incr...
# 23  [reports, of, community, spread, of, in, calif...
# 24  [cdc, amp, also, reported, 2, ppl, have, teste...
# 25  [today, and, cdc, reported, the, death, of, a,...
# 26  [cdc, does, not, currently, recommend, the, ge...
# 27  [cdc, and, public, health, authorities, have, ...
#
#                                     normalized_tokens  year month
# 0   [asymptomatic, pre, symptomatic, nurse, home, ...  2020    03
# 1   [simple, daily, precaution, help, prevent, spr...  2020    03
# 2   [new, cdc, health, alert, network, advisory, s...  2020    03
# 3   [parent, stay, flexible, learn, schedule, kid,...  2020    03
# 4   [march, state, territory, report, community, s...  2020    03
# 5   [cdc, recommend, traveler, defer, cruise, trav...  2020    03
# 6   [role, play, reduce, slow, transmission, physi...  2020    03
# 7   [new, report, show, disease, amp, death, covid...  2020    03
# 8   [role, play, reduce, amp, slow, transmission, ...  2020    03
# 9   [new, death, associate, occur, old, adult, rol...  2020    03
# 10  [old, adult, people, w, severe, chronic, medic...  2020    03
# 11  [q, ideal, community, response, occur, protect...  2020    03
# 12  [q, individual, sicken, covid, virus, long, lo...  2020    03
# 13  [march, state, local, public, health, lab, sta...  2020    03
# 14  [currently, case, california, washington, stat...  2020    03
# 15  [estimate, case, worldwide, march, state, new,...  2020    03
# 16  [old, adult, amp, ppl, w, severe, chronic, med...  2020    03
# 17  [prevention, action, include, routinely, clean...  2020    03
# 18  [old, adult, amp, people, severe, chronic, med...  2020    03
# 19  [coca, today, pm, et, available, coca, faceboo...  2020    03
# 20  [great, risk, infection, close, contact, peopl...  2020    03
# 21  [public, health, response, threat, include, ac...  2020    03
# 22  [people, increase, risk, depend, exposure, gre...  2020    02
# 23  [report, community, spread, california, oregon...  2020    02
# 24  [cdc, amp, report, ppl, test, positive, hospit...  2020    02
# 25  [today, cdc, report, death, person, hospitaliz...  2020    02
# 26  [cdc, currently, recommend, general, public, u...  2020    02
# 27  [cdc, public, health, authority, implement, ag...  2020    02

# %%
tweets02 = tweets_df[((tweets_df["month"] == '04') |(tweets_df["month"] == '05') | (tweets_df["month"] == '06')) & (tweets_df["year"] == '2020')]
tweets02 = tweets02.reset_index(drop=True)
tweets02
# Out:
#                      id date      time username  \
# 0   1278069913668780032   30  16:56:27   cdcgov
# 1   1278019979368189954   30  13:38:02   cdcgov
# 2   1278012224070656000   30  13:07:13   cdcgov
# 3   1277649631913168896   29  13:06:24   cdcgov
# 4   1277643246894821377   29  12:41:02   cdcgov
# ..                  ...  ...       ...      ...
# 78  1247594247643115520   07  14:37:02   cdcgov
# 79  1247211280261427201   06  13:15:15   cdcgov
# 80  1246789693053833216   05  09:20:01   cdcgov
# 81  1245463960712810502   01  17:32:02   cdcgov
# 82  1245396997319901185   01  13:05:57   cdcgov
#
#                                                 tweet  \
# 0   if you tested positive for and have no symptom...
# 1   survey of people with covid 19 in colorado fin...
# 2   a survey of covid 19 positive patients found t...
# 3   correctional facilities face unique challenges...
# 4   the latest cdc shows indicators used to monito...
# ..                                                ...
# 78  growing evidence suggests can spread before pe...
# 79  new report is the first to look at illness in ...
# 80  need information in a different language check...
# 81  as of april 1 46 us states and 1 us territory ...
# 82  new report on in singapore shows that some clu...
#
#                          hashtags  \
# 0                       [covid19]
# 1                       [covid19]
# 2                       [covid19]
# 3                              []
# 4   [covidview, covid19, covid19]
# ..                            ...
# 78         [covid19, coronavirus]
# 79                      [covid19]
# 80                      [covid19]
# 81         [coronavirus, covid19]
# 82                      [covid19]
#
#                                       tokenized_tweet  \
# 0   [if, you, tested, positive, for, and, have, no...
# 1   [survey, of, people, with, covid, 19, in, colo...
# 2   [a, survey, of, covid, 19, positive, patients,...
# 3   [correctional, facilities, face, unique, chall...
# 4   [the, latest, cdc, shows, indicators, used, to...
# ..                                                ...
# 78  [growing, evidence, suggests, can, spread, bef...
# 79  [new, report, is, the, first, to, look, at, il...
# 80  [need, information, in, a, different, language...
# 81  [as, of, april, 1, 46, us, states, and, 1, us,...
# 82  [new, report, on, in, singapore, shows, that, ...
#
#                                     normalized_tokens  year month
# 0   [test, positive, symptom, stay, home, away, pe...  2020    06
# 1   [survey, people, covid, colorado, find, half, ...  2020    06
# 2   [survey, covid, positive, patient, find, half,...  2020    06
# 3   [correctional, facility, face, unique, challen...  2020    06
# 4   [late, cdc, show, indicator, monitor, remain, ...  2020    06
# ..                                                ...   ...   ...
# 78  [grow, evidence, suggest, spread, people, symp...  2020    04
# 79  [new, report, look, illness, kid, u, s, case, ...  2020    04
# 80  [need, information, different, language, check...  2020    04
# 81  [april, state, territory, report, community, s...  2020    04
# 82  [new, report, singapore, show, cluster, case, ...  2020    04
#
# [83 rows x 10 columns]

# %%
tweets03 = tweets_df[((tweets_df["month"] == '07') |(tweets_df["month"] == '08') | (tweets_df["month"] == '09')) & (tweets_df["year"] == '2020')]
tweets03 = tweets03.reset_index(drop=True)
tweets03
# Out:
#                       id date      time username  \
# 0    1311424974989807618   30  17:57:33   cdcgov
# 1    1311392895375740929   30  15:50:05   cdcgov
# 2    1310990987058188289   29  13:13:03   cdcgov
# 3    1310274261832159238   27  13:45:02   cdcgov
# 4    1309614375989399553   25  18:02:53   cdcgov
# ..                   ...  ...       ...      ...
# 97   1280630195406483457   07  18:30:06   cdcgov
# 98   1280622880229863425   07  18:01:02   cdcgov
# 99   1280562227980800000   07  14:00:01   cdcgov
# 100  1280224757275717632   06  15:39:02   cdcgov
# 101  1279817314234294272   05  12:40:00   cdcgov
#
#                                                  tweet  \
# 0    increases in vary by urbanization over the las...
# 1    join the next cdc covid 19 partner update call...
# 2    new shows infections among 18 22 year olds inc...
# 3    in public to help slow the spread of covid 19 ...
# 4    as of september 21 national forecasts predict ...
# ..                                                 ...
# 97   as of july 6 in the last 7 days 9 states have ...
# 98   the latest cdc report shows that activity rema...
# 99   is one of the best tools to avoid being expose...
# 100  stigma hurts everyone no single group ethnicit...
# 101  take simple daily precautions to help prevent ...
#
#                                               hashtags  \
# 0                                            [covid19]
# 1                       [covid19, sciencenews, health]
# 2                                            [covid19]
# 3                                 [wearamask, covid19]
# 4                                            [covid19]
# ..                                                 ...
# 97                                           [covid19]
# 98                                [covidview, covid19]
# 99   [socialdistancing, covid19, slowthespread, soc...
# 100                                          [covid19]
# 101                                          [covid19]
#
#                                        tokenized_tweet  \
# 0    [increases, in, vary, by, urbanization, over, ...
# 1    [join, the, next, cdc, covid, 19, partner, upd...
# 2    [new, shows, infections, among, 18, 22, year, ...
# 3    [in, public, to, help, slow, the, spread, of, ...
# 4    [as, of, september, 21, national, forecasts, p...
# ..                                                 ...
# 97   [as, of, july, 6, in, the, last, 7, days, 9, s...
# 98   [the, latest, cdc, report, shows, that, activi...
# 99   [is, one, of, the, best, tools, to, avoid, bei...
# 100  [stigma, hurts, everyone, no, single, group, e...
# 101  [take, simple, daily, precautions, to, help, p...
#
#                                      normalized_tokens  year month
# 0    [increase, vary, urbanization, day, covid, cas...  2020    09
# 1    [join, cdc, covid, partner, update, monday, oc...  2020    09
# 2    [new, show, infection, year, old, increase, ea...  2020    09
# 3    [public, help, slow, spread, covid, sure, wear...  2020    09
# 4    [september, national, forecast, predict, new, ...  2020    09
# ..                                                 ...   ...   ...
# 97   [july, day, state, report, new, case, wear, cl...  2020    07
# 98   [late, cdc, report, show, activity, remain, pe...  2020    07
# 99   [well, tool, avoid, expose, help, covid, key, ...  2020    07
# 100  [stigma, hurt, single, group, ethnicity, popul...  2020    07
# 101  [simple, daily, precaution, help, prevent, spr...  2020    07
#
# [102 rows x 10 columns]

# %%
tweets04 = tweets_df[((tweets_df["month"] == '10') |(tweets_df["month"] == '11') | (tweets_df["month"] == '12')) & (tweets_df["year"] == '2020')]
tweets04 = tweets04.reset_index(drop=True)
tweets04
# Out:
#                       id date      time username  \
# 0    1344708066663690242   31  13:12:41   cdcgov
# 1    1344406982292287491   30  17:16:17   cdcgov
# 2    1344342593245765632   30  13:00:25   cdcgov
# 3    1344335449012252675   30  12:32:02   cdcgov
# 4    1344025513640292352   29  16:00:27   cdcgov
# ..                   ...  ...       ...      ...
# 120  1313153987617710080   05  12:28:02   cdcgov
# 121  1312152893508644864   02  18:10:03   cdcgov
# 122  1312110862501507073   02  15:23:02   cdcgov
# 123  1312092755124842496   02  14:11:04   cdcgov
# 124  1311726346230542342   01  13:55:06   cdcgov
#
#                                                  tweet             hashtags  \
# 0    new shows covid 19 antigen tests can be fast a...                   []
# 1    cases of covid 19 are highest among people age...                   []
# 2    covid 19 science update read the latest resear...            [covid19]
# 3    has killed more than 300 000 people in the uni...            [covid19]
# 4    pregnant you may discuss vaccines with your do...  [covid19, pregnant]
# ..                                                 ...                  ...
# 120  attend todays cdc covid 19 partner update call...    [covid19, health]
# 121   blood samples are tested to determine if some...       [dyk, covid19]
# 122  college administrators use cdcs new monitoring...            [covid19]
# 123  as of september 28 national forecasts predict ...            [covid19]
# 124  school administrators use cdcs new monitoring ...            [covid19]
#
#                                        tokenized_tweet  \
# 0    [new, shows, covid, 19, antigen, tests, can, b...
# 1    [cases, of, covid, 19, are, highest, among, pe...
# 2    [covid, 19, science, update, read, the, latest...
# 3    [has, killed, more, than, 300, 000, people, in...
# 4    [pregnant, you, may, discuss, vaccines, with, ...
# ..                                                 ...
# 120  [attend, todays, cdc, covid, 19, partner, upda...
# 121  [blood, samples, are, tested, to, determine, i...
# 122  [college, administrators, use, cdcs, new, moni...
# 123  [as, of, september, 28, national, forecasts, p...
# 124  [school, administrators, use, cdcs, new, monit...
#
#                                      normalized_tokens  year month
# 0    [new, show, covid, antigen, test, fast, inexpe...  2020    12
# 1    [case, covid, high, people, age, age, group, m...  2020    12
# 2    [covid, science, update, read, late, research,...  2020    12
# 3    [kill, people, unite, state, datum, help, save...  2020    12
# 4    [pregnant, discuss, vaccine, doctor, require, ...  2020    12
# ..                                                 ...   ...   ...
# 120  [attend, today, cdc, covid, partner, update, m...  2020    10
# 121  [blood, sample, test, determine, not, symptom,...  2020    10
# 122  [college, administrator, use, cdcs, new, monit...  2020    10
# 123  [september, national, forecast, predict, new, ...  2020    10
# 124  [school, administrator, use, cdcs, new, monito...  2020    10
#
# [125 rows x 10 columns]

# %%
tweets0121 = tweets_df[tweets_df["year"] == '2021']
tweets0121 = tweets0121.reset_index(drop=True)
tweets0121
# Out:
#                      id date      time username  \
# 0   1363921515922796547   22  13:40:04   cdcgov
# 1   1363885801755533313   22  11:18:09   cdcgov
# 2   1362865816765661190   19  15:45:06   cdcgov
# 3   1362849192130080772   19  14:39:02   cdcgov
# 4   1362510972162867206   18  16:15:04   cdcgov
# ..                  ...  ...       ...      ...
# 88  1346472152749334528   05  10:02:32   cdcgov
# 89  1346225903039295488   04  17:44:01   cdcgov
# 90  1346165771400065028   04  13:45:05   cdcgov
# 91  1345801601403916288   03  13:38:00   cdcgov
# 92  1345783990637223937   03  12:28:01   cdcgov
#
#                                                 tweet        hashtags  \
# 0    covid 19 and flu can both cause fever and cou...  [dyk, covid19]
# 1   a new looks at in georgia elementary schools t...       [covid19]
# 2   officials are concerned about 3 variants detec...       [covid19]
# 3   getting a vaccine is important for adults with...       [covid19]
# 4    you need two mrna vaccine doses to get the mo...  [dyk, covid19]
# ..                                                ...             ...
# 88  however the report also shows that people with...              []
# 89  vaccines are an important tool to help stop th...       [covid19]
# 90  stay on top of data from your community and ar...       [covid19]
# 91  things to know vaccine some side effects are n...       [covid19]
# 92  if someone you live with is 65 or older or has...       [covid19]
#
#                                       tokenized_tweet  \
# 0   [covid, 19, and, flu, can, both, cause, fever,...
# 1   [a, new, looks, at, in, georgia, elementary, s...
# 2   [officials, are, concerned, about, 3, variants...
# 3   [getting, a, vaccine, is, important, for, adul...
# 4   [you, need, two, mrna, vaccine, doses, to, get...
# ..                                                ...
# 88  [however, the, report, also, shows, that, peop...
# 89  [vaccines, are, an, important, tool, to, help,...
# 90  [stay, on, top, of, data, from, your, communit...
# 91  [things, to, know, vaccine, some, side, effect...
# 92  [if, someone, you, live, with, is, 65, or, old...
#
#                                     normalized_tokens  year month
# 0   [covid, flu, cause, fever, cough, shortness, b...  2021    02
# 1   [new, look, georgia, elementary, school, study...  2021    02
# 2   [official, concern, variant, detect, u, s, b, ...  2021    02
# 3   [get, vaccine, important, adult, certain, heal...  2021    02
# 4   [need, mrna, vaccine, dose, protection, covid,...  2021    02
# ..                                                ...   ...   ...
# 88  [report, show, people, symptom, negative, anti...  2021    01
# 89  [vaccine, important, tool, help, stop, pandemi...  2021    01
# 90  [stay, datum, community, world, cdcs, covid, d...  2021    01
# 91  [thing, know, vaccine, effect, normal, case, c...  2021    01
# 92  [live, old, underlie, condition, likely, sick,...  2021    01
#
# [93 rows x 10 columns]

# %%
# %store tweets0121
# Out:
# Stored 'tweets0121' (DataFrame)

# %%
# %store tweets01
# Out:
# Stored 'tweets01' (DataFrame)

# %%
# %store tweets02
# Out:
# Stored 'tweets02' (DataFrame)

# %%
# %store tweets03
# Out:
# Stored 'tweets03' (DataFrame)

# %%
# %store tweets04
# Out:
# Stored 'tweets04' (DataFrame)

# %%
cdc_tweets = []
for line in open('data/cdc_twitter_since_2020.json', 'r', encoding='utf-8'):
    cdc_tweets.append(json.loads(line))
    
cdc_df = pd.DataFrame(cdc_tweets)
cdc_df = cdc_df[['id', 'date', 'time', 'tweet']]
cdc_df['year'] = cdc_df['date'].apply(lambda x: x.split('-')[0])
cdc_df['month'] = cdc_df['date'].apply(lambda x: x.split('-')[1])
cdc_df['date'] = cdc_df['date'].apply(lambda x: x.split('-')[2])
cdc_df
# Out:
#                        id date      time  \
# 0     1363979677098991620   22  17:31:11
# 1     1363934848868564996   22  14:33:03
# 2     1363921515922796547   22  13:40:04
# 3     1363917733033897987   22  13:25:02
# 4     1363911555440664579   22  13:00:29
# ...                   ...  ...       ...
# 2571  1212828138734010368   02  15:08:56
# 2572  1212797510923800576   02  13:07:13
# 2573  1212774053783724033   02  11:34:01
# 2574  1212758200338006016   02  10:31:01
# 2575  1212396317168881664   01  10:33:01
#
#                                                   tweet  year month
# 0     #COVID19 vaccines are a safer way to build pro...  2021    02
# 1     New &amp; updated #COVID19 videos are now avai...  2021    02
# 2     #DYK? COVID-19 and flu can both cause fever an...  2021    02
# 3     #DYK? Symptoms of #COVID19 may overlap with sy...  2021    02
# 4     “[We are] working with national, state and loc...  2021    02
# ...                                                 ...   ...   ...
# 2571  OUTBREAK UPDATE: As of 12/27, 2,561 hospitaliz...  2020    01
# 2572  NEW Report: Recommendations for Providing Qual...  2020    01
# 2573  #DYK? At least 1.7 million adults in the U.S. ...  2020    01
# 2574  Vaccinate your son or daughter against HPV whe...  2020    01
# 2575  CDC wishes you and your family a healthy and #...  2020    01
#
# [2576 rows x 6 columns]

# %%
all01 = cdc_df[((cdc_df["month"] == '02') |(cdc_df["month"] == '03')) & (cdc_df["year"] == '2020')]
all01 = all01.reset_index(drop=True)
# Out:
#                       id date      time  \
# 0    1245121663714328576   31  18:51:52
# 1    1245121661688590341   31  18:51:52
# 2    1245084712126865410   31  16:25:02
# 3    1245038414929502208   31  13:21:04
# 4    1244708498795044864   30  15:30:06
# ..                   ...  ...       ...
# 339  1223723965887197184   01  16:45:03
# 340  1223704078846513157   01  15:26:02
# 341  1223693751769419777   01  14:45:00
# 342  1223672054291095553   01  13:18:47
# 343  1223627565878788096   01  10:22:00
#
#                                                  tweet  year month
# 0    Community mitigation actions can push the peak...  2020    03
# 1    #DYK? Disease outbreaks, including pandemics, ...  2020    03
# 2    Retirement community staff: Lower the chances ...  2020    03
# 3    While infection from #COVID19 is a concern for...  2020    03
# 4    Worried about your pet during the #COVID19 out...  2020    03
# ..                                                 ...   ...   ...
# 339  Outbreak response in action: #CDC staff are ac...  2020    02
# 340  You may know all the stats for your favorite p...  2020    02
# 341  Serving wings? Don’t wash chicken. To clean it...  2020    02
# 342  @yitao_yue Thank you.  2019 Novel Coronavirus,...  2020    02
# 343  Authorities in China identified the novel (new...  2020    02
#
# [344 rows x 6 columns]

# %%
all01 = all01.drop(all01[all01['date']<"25"].index)
all01 = all01.reset_index(drop=True)
all01
# Out:
#                      id date      time  \
# 0   1245121663714328576   31  18:51:52
# 1   1245121661688590341   31  18:51:52
# 2   1245084712126865410   31  16:25:02
# 3   1245038414929502208   31  13:21:04
# 4   1244708498795044864   30  15:30:06
# ..                  ...  ...       ...
# 83  1232394892707553281   25  15:00:13
# 84  1232387286849015808   25  14:30:00
# 85  1232366410313224193   25  13:07:03
# 86  1232360618990108673   25  12:44:02
# 87  1232342500909764609   25  11:32:02
#
#                                                 tweet  year month
# 0   Community mitigation actions can push the peak...  2020    03
# 1   #DYK? Disease outbreaks, including pandemics, ...  2020    03
# 2   Retirement community staff: Lower the chances ...  2020    03
# 3   While infection from #COVID19 is a concern for...  2020    03
# 4   Worried about your pet during the #COVID19 out...  2020    03
# ..                                                ...   ...   ...
# 83  Visit the David J. Sencer CDC Museum during AT...  2020    02
# 84  Healthcare Professionals: Have you registered ...  2020    02
# 85  CDC and public health authorities have impleme...  2020    02
# 86  FREE CE: Watch the new #CDCGrandRounds maintai...  2020    02
# 87  #Parents: if your child gets sick with #flu, m...  2020    02
#
# [88 rows x 6 columns]

# %%
all02 = cdc_df[((cdc_df["month"] == '04') |(cdc_df["month"] == '05') |(cdc_df["month"] == '06')) & (cdc_df["year"] == '2020')]
all02 = all02.reset_index(drop=True)
all02
# Out:
#                       id date      time  \
# 0    1278069913668780032   30  16:56:27
# 1    1278034071143223296   30  14:34:01
# 2    1278028040786841600   30  14:10:04
# 3    1278019979368189954   30  13:38:02
# 4    1278012224070656000   30  13:07:13
# ..                   ...  ...       ...
# 500  1245439602200018944   01  15:55:14
# 501  1245439600472084486   01  15:55:14
# 502  1245439598412681216   01  15:55:14
# 503  1245409852870078468   01  13:57:02
# 504  1245396997319901185   01  13:05:57
#
#                                                  tweet  year month
# 0    If you tested positive for #COVID19 and have n...  2020    06
# 1    Headed to a beach, lake, or river this summer?...  2020    06
# 2    Healthcare providers: Learn how telehealth tec...  2020    06
# 3    Survey of people with COVID-19 in Colorado fin...  2020    06
# 4    A survey of COVID-19-positive patients found t...  2020    06
# ..                                                 ...   ...   ...
# 500  Different parts of the country can be at diffe...  2020    04
# 501  Actions to reduce spread of the virus, such as...  2020    04
# 502  #DYK? Nationally the U.S. is in what is called...  2020    04
# 503  #HCPs: COCA Call on Thurs, April 2, at 2pm ET ...  2020    04
# 504  New @CDCMMWR report on #COVID19 in Singapore s...  2020    04
#
# [505 rows x 6 columns]

# %%
all03 = cdc_df[((cdc_df["month"] == '07') |(cdc_df["month"] == '08') |(cdc_df["month"] == '09')) & (cdc_df["year"] == '2020')]
all03 = all03.reset_index(drop=True)
all03
# Out:
#                       id date      time  \
# 0    1311424974989807618   30  17:57:33
# 1    1311424971613319169   30  17:57:32
# 2    1311402982735572992   30  16:30:10
# 3    1311392895375740929   30  15:50:05
# 4    1311376273067909120   30  14:44:02
# ..                   ...  ...       ...
# 565  1278429429597954048   01  16:45:02
# 566  1278420368273870849   01  16:09:02
# 567  1278387974191951872   01  14:00:19
# 568  1278373769174822913   01  13:03:52
# 569  1278346403757142017   01  11:15:07
#
#                                                  tweet  year month
# 0    Increases in #COVID19 vary by urbanization. Ov...  2020    09
# 1    As of September 27, #COVID19 cases were trendi...  2020    09
# 2    Salmonella Outbreak: 32 people in 17 states ha...  2020    09
# 3    Join the next CDC COVID-19 Partner Update Call...  2020    09
# 4    With over 87.5 million doses of flu vaccine al...  2020    09
# ..                                                 ...   ...   ...
# 565  HCPs: mothers who were unable to initiate brea...  2020    07
# 566  If you plan to use rideshares or taxis, protec...  2020    07
# 567  If you’re feeling ill or have health concerns,...  2020    07
# 568  Repeated laboratory testing combined with infe...  2020    07
# 569  Read. Spray. Flip. Spray. Dry. This summer, ap...  2020    07
#
# [570 rows x 6 columns]

# %%
all04 = cdc_df[((cdc_df["month"] == '10') |(cdc_df["month"] == '11') |(cdc_df["month"] == '12')) & (cdc_df["year"] == '2020')]
all04 = all04.reset_index(drop=True)
all04
# Out:
#                       id date      time  \
# 0    1344769057720070144   31  17:15:02
# 1    1344760752587071489   31  16:42:02
# 2    1344741626430816256   31  15:26:02
# 3    1344735073753387009   31  15:00:00
# 4    1344725021198065665   31  14:20:03
# ..                   ...  ...       ...
# 633  1311762315872788486   01  16:18:02
# 634  1311751242721394689   01  15:34:02
# 635  1311726346230542342   01  13:55:06
# 636  1311715168489963521   01  13:10:41
# 637  1311693884599291916   01  11:46:06
#
#                                                  tweet  year month
# 0    How do you keep an almost-eradicated virus in ...  2020    12
# 1    Attending a small celebration? Take steps to m...  2020    12
# 2    An ongoing CDC study of household spread of #C...  2020    12
# 3    How do we know if vaccines are safe? @aasian a...  2020    12
# 4    New @CDCMMWR illustrates data showing #COVID19...  2020    12
# ..                                                 ...   ...   ...
# 633  #Parent: Keep your #child healthy by bringing ...  2020    10
# 634  Quitting smoking can be good for your mental h...  2020    10
# 635  School administrators: Use CDC’s new monitorin...  2020    10
# 636  A new @CDCMMWR report offers a snapshot of the...  2020    10
# 637  Getting a #fluvaccine is more important than e...  2020    10
#
# [638 rows x 6 columns]

# %%
all0121 = cdc_df[cdc_df["year"] == '2021']
all0121 = all0121.reset_index(drop=True)
all0121
# Out:
#                       id date      time  \
# 0    1363979677098991620   22  17:31:11
# 1    1363934848868564996   22  14:33:03
# 2    1363921515922796547   22  13:40:04
# 3    1363917733033897987   22  13:25:02
# 4    1363911555440664579   22  13:00:29
# ..                   ...  ...       ...
# 333  1345783990637223937   03  12:28:01
# 334  1345486284161228802   02  16:45:02
# 335  1345399729895727106   02  11:01:06
# 336  1345103763149910016   01  15:25:02
# 337  1345070785891885057   01  13:14:00
#
#                                                  tweet  year month
# 0    #COVID19 vaccines are a safer way to build pro...  2021    02
# 1    New &amp; updated #COVID19 videos are now avai...  2021    02
# 2    #DYK? COVID-19 and flu can both cause fever an...  2021    02
# 3    #DYK? Symptoms of #COVID19 may overlap with sy...  2021    02
# 4    “[We are] working with national, state and loc...  2021    02
# ..                                                 ...   ...   ...
# 333  If someone you live with is 65 or older or has...  2021    01
# 334  If you have recovered from #COVID19, still #We...  2021    01
# 335  Some efforts to stop #COVID19 can have uninten...  2021    01
# 336  When you leave home 🏘️, you could be exposed t...  2021    01
# 337  #COVID19 vaccines are one of many important to...  2021    01
#
# [338 rows x 6 columns]

# %% [markdown]
# # plots

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams.update({'font.family' : 'Times New Roman', 'font.size': 23})
fig = plt.figure(figsize = (12,8))
label_list = ['2020 02.25-03', '2020 04-06', '2020 07-09', '2020 10-12', '2021 01-02.22']
num_list1 = [len(tweets01), len(tweets02), len(tweets03), len(tweets04), len(tweets0121)]
num_list2 = [len(all01)-len(tweets01), len(all02)-len(tweets02), len(all03)-len(tweets03), 
             len(all04)-len(tweets04), len(all0121)-len(tweets0121)]
num_list3 = [len(all01), len(all02), len(all03), len(all04), len(all0121)]
x = range(len(num_list1))
rects1 = plt.bar(x=x, height=num_list1, width=0.45, alpha=0.8, label="COVID-related")
rects2 = plt.bar(x=x, height=num_list2, width=0.45, label="Total", bottom=num_list1)

count = 0
count2 = 0
for i in num_list1:
    plt.text(count,i+0.5, str('{:.2f}'.format(num_list1[count]/num_list3[count] *100)) +'%', \
    ha='center') #位置，高度，内容，居中
    count+=1 #增加百分比
for i in num_list3: 
    plt.text(count2,i+20, str('{}'.format(num_list3[count2])), ha='center')
    count2+=1
    
plt.ylim(0, 900)
plt.ylabel("Number")
plt.xticks(x, label_list)
plt.xlabel("Time")
plt.title("Number of CDC Tweets by Quarters")
plt.legend()
plt.show()
